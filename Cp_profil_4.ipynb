# %%
# Зчитування координат (x; y) з файлу NACA 0012.dat і координат (x; Cpi) з файлу Cp_6.0.txt та їх наступна побудова
# визначаємо сумарний момент на лінії y0=-0.3
import math
import numpy as np
import matplotlib.pyplot as plt
def Moment(x0,y0,x1,y1,x2,y2,Cp):
    Lx=x2-x1
    Ly=y2-y1
    L=(Lx*Lx+Ly*Ly)**0.5
    rx=x1-x0
    ry=y1-y0
    r=(rx*rx+ry*ry)**0.5
    rL=rx*Lx+ry*Ly
    cosA=rL/(r*L)
    d=r*cosA
    F=Cp*L
    M=F*d
    return M

L1='NACA 0012.dat'
L2='cp\Cp_1.0.txt'
L3='cp\Cp_6.0.txt'
F=[1.0,6.0] #поворот на f°
y0=0.6

X1,Y1=[],[]
# відкриваємо файл для зчитування даних
f1 = open(L1, mode='r')
i=0
for row in f1:
    if i>0:
        s=row.split(' ')
        if len(s)==7:
            s=[s[1], s[6]]
        else:
            s=[s[1], s[5]]        
        s1=list(map(float, s))
        X1.append(s1[0])
        Y1.append(s1[1])
    i=i+1
f1.close()    
# поворот на f° та зміщення на 0.5 СК
f=F[0]*np.pi/180 #f у радіанах
X11=np.array(X1)
Y11=np.array(Y1)
XX1=(X11-0.5)*np.cos(f)+Y11*np.sin(f)+0.5
YY1=Y11*np.cos(f)-(X11-0.5)*np.sin(f)+y0
# будуємо з зчитаних даних профіль
plt.plot(XX1, YY1, '-og',label='профіль1', markersize=1)

X2,Y2=[],[]
f2 = open(L2, mode='r')
i=0
for row in f2:
    if i>5 and i<205:
        s=row.split(' ')
        if len(s[5])>1:
            s=[s[1], s[5]]
        elif len(s[4])>1:
            s=[s[1], s[4]]        
        s1=list(map(float, s))
        X2.append(s1[0])
        Y2.append(-s1[1])
    i=i+1
f2.close()

# лінія ЦМ
Y0=[0 for i in range(-10,16)]
X0=[i/10 for i in range(-10,16)]

MM1=[] #сумарний момент сил, що діє на профіль відносно точки (x0;y0)
for i in range(len(X0)):    
    x0=X0[i]
    MM=[] #момент сили, що діє на точку профілю (XX1[j];YY1[j]) відносно точки (x0;y0)
    for j in range(len(X1)-1):
        MM.append(Moment(x0,0,XX1[j],YY1[j],XX1[j+1],YY1[j+1],Y2[j]))
    MM1.append(round(sum(MM),4))
    
Mmin=min(map(abs, MM1))
for u in range(len(MM1)):
    if abs(MM1[u])==Mmin:
        nomer=u
        break
Mmin=MM1[nomer]
print('Mmin=',Mmin, 'Хцм=',X0[nomer],'Yцм=',0)

plt.plot(X0, MM1, '-om',label=r'$\Sigma M_i; \alpha =$'+str(round(f*180/np.pi,1))+r'$^{\circ}; \ y_0=$'+str(y0), markersize=2, linewidth=1)
plt.plot(X0, Y0, '-ok',label='ЦМ', markersize=2, linewidth=1)
# кутовий коефіцієнт прямої сумарних моментів
k=(MM1[1]-MM1[0])/(X0[1]-X0[0])
print('kM=',round(k,4))

plt.plot(0, 0, '-oy', markersize=3) #центр СК
plt.annotate('центр СК', xy=(0,0.05), fontsize=7)
plt.plot(0.5, y0, '-ob', markersize=3) #центр профілю
plt.annotate('центр профілю', xy=(0.5,y0), fontsize=7)
plt.plot(X0[nomer], Mmin, '-og', markersize=5) #мінімальний момент
plt.annotate('Mmin; ЦМ*', xy=(X0[nomer],0.05), fontsize=7)

# ------------------------------------------
# поворот на f° та зміщення на 0.5 СК
f=F[1]*np.pi/180 #f у радіанах
X11=np.array(X1)
Y11=np.array(Y1)
XX1=(X11-0.5)*np.cos(f)+Y11*np.sin(f)+0.5
YY1=Y11*np.cos(f)-(X11-0.5)*np.sin(f)+y0
# будуємо з зчитаних даних профіль
plt.plot(XX1, YY1, '-or',label='профіль2', markersize=1)

X3,Y3=[],[]
f3 = open(L3, mode='r')
i=0
for row in f3:
    if i>5 and i<205:
        s=row.split(' ')
        if len(s[5])>1:
            s=[s[1], s[5]]
        elif len(s[4])>1:
            s=[s[1], s[4]]        
        s1=list(map(float, s))
        X3.append(s1[0])
        Y3.append(-s1[1])
    i=i+1
f3.close()
MM1=[] #сумарний момент сил, що діє на профіль відносно точки (x0;y0)
for i in range(len(X0)):    
    x0=X0[i]
    MM=[] #момент сили, що діє на точку профілю (XX1[j];YY1[j]) відносно точки (x0;y0)
    for j in range(len(X1)-1):
        MM.append(Moment(x0,0,XX1[j],YY1[j],XX1[j+1],YY1[j+1],Y3[j]))
    MM1.append(round(sum(MM),4))
Mmin=min(map(abs, MM1))
for u in range(len(MM1)):
    if abs(MM1[u])==Mmin:
        nomer=u
        break
Mmin=MM1[nomer]
print('Mmin=',Mmin, 'Хцм=',X0[nomer],'Yцм=',0)
plt.plot(X0, MM1, '-oc',label=r'$\Sigma M_i; \alpha =$'+str(round(f*180/np.pi,1))+r'$^{\circ}; \ y_0=$'+str(y0), markersize=2, linewidth=1)
# кутовий коефіцієнт прямої сумарних моментів
k=(MM1[1]-MM1[0])/(X0[1]-X0[0])
print('kM=',round(k,4))

plt.plot(0.27,0, '-ob', markersize=3) #фокус профілю
plt.annotate('фокус', xy=(0.27,-0.05), fontsize=7)

plt.ylabel('y, -Cp, M')
plt.xlabel('x')
plt.title('NACA 0012')
plt.axis('equal')#однакові масштаби для x та y
plt.legend()
plt.ylim(-1.0, 1.0)
plt.xlim(-1.1, 1.5)
plt.show()

# 'b' blue
# 'g' green
# 'r' red
# 'c' cyan
# 'm' magenta
# 'y' yellow
# 'k' black
# 'w' white
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\C'
# <>:22: SyntaxWarning: invalid escape sequence '\C'
# <>:21: SyntaxWarning: invalid escape sequence '\C'
# <>:22: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\admin\AppData\Local\Temp\ipykernel_12564\3941331700.py:21: SyntaxWarning: invalid escape sequence '\C'
#   L2='cp\Cp_1.0.txt'
# C:\Users\admin\AppData\Local\Temp\ipykernel_12564\3941331700.py:22: SyntaxWarning: invalid escape sequence '\C'
#   L3='cp\Cp_6.0.txt'
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.
# Mmin= -0.0055 Хцм= 0.2 Yцм= 0
# kM= 0.116
# Mmin= 0.0246 Хцм= 0.3 Yцм= 0
# kM= 0.713
